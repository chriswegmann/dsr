# %%
#!/usr/bin/env python

import random, math
import json, os
import requests
import time
import datetime

fraudZip = [random.randint(math.pow(10, 3), 2*math.pow(10, 4)) for i in range(0, 1000)]
def zipCode(fraud):
#	if(fraud and random.randint(0, 10) < 5):
#		return fraudZip[random.randint(0, 100-2)]
#	else:
	return random.randint(math.pow(10, 3), math.pow(10, 4))

def transactionId():
    return random.randint(math.pow(10,9), math.pow(10, 10))

def fraudCategory():
    rand = random.randint(0, 10)
    if(rand > 5):
        return 4
    if(rand > 2):
        return 3
    return rand

def basket(fraud):
    size = max((int)(random.gauss(5, 3)),1)
    if(fraud):
        return [fraudCategory() for i in range(0, size)]
    else:
        return [random.randint(0, 4) for i in range(0, size)]

def totalAmount(fraud, itemsInBasket, i):
    factor = 1 if i < 2000 else 10
    if(fraud):
        return itemsInBasket*max((int)(random.gauss(70, 30)),10)/factor
    else:
        return itemsInBasket*max((int)(random.gauss(50, 30)),10)/factor

def jsonLine(i):
    fraud = random.randint(0, 100) < 3
    basketItems = basket(fraud)
    return json.dumps({
        "transactionId": transactionId(),
        "basket": basketItems if random.randint(0, 10) > 1 else None,
        "zipCode": zipCode(fraud) if random.randint(0, 10) > 1 else None,
        "totalAmount": totalAmount(fraud, len(basketItems), i) if random.randint(0, 10) > 1 else None
        })

# %%
for i in range(1, 10000):
    print("Sending request...")
    headers = {'content-type': 'application/json'}
    print(jsonLine(i))
    r = requests.post("http://localhost:5000/predict", data=jsonLine(i), headers=headers)
    print("Received answer: " + str(r.text))
    #time.sleep(1)
# Out:
# Sending request...
# {"transactionId": 2762272045, "basket": [0, 4, 2, 0, 1, 2, 0], "zipCode": null, "totalAmount": 448.0}
# Received answer: {"probability":0.0011506088318738801}
#
# Sending request...
# {"transactionId": 3198259561, "basket": [4, 3, 1, 1, 3, 1, 3], "zipCode": 9844, "totalAmount": null}
# Received answer: {"probability":0.010086988510373155}
#
# Sending request...
# {"transactionId": 2330728030, "basket": [3, 4, 4, 2, 4, 4, 3, 1], "zipCode": null, "totalAmount": 448.0}
# Received answer: {"probability":0.49304228686252494}
#
# Sending request...
# {"transactionId": 4277945501, "basket": [4, 2, 0, 3, 4, 0], "zipCode": 5705, "totalAmount": 348.0}
# Received answer: {"probability":0.017241738964523773}
#
# Sending request...
# {"transactionId": 4549656722, "basket": [1], "zipCode": 7771, "totalAmount": null}
# Received answer: {"probability":0.009349173658563026}
#
# Sending request...
# {"transactionId": 3219122111, "basket": null, "zipCode": 9155, "totalAmount": 72.0}
# Received answer: {"probability":0.010943366402050972}
#
# Sending request...
# {"transactionId": 6564756729, "basket": [4, 1], "zipCode": 6469, "totalAmount": null}
# Received answer: {"probability":0.003968109783767297}
#
# Sending request...
# {"transactionId": 2618081638, "basket": null, "zipCode": 3639, "totalAmount": 784.0}
# Received answer: {"probability":0.0007817220638951082}
#
# Sending request...
# {"transactionId": 2294254773, "basket": [0, 3, 2, 0, 4, 2, 4], "zipCode": 3586, "totalAmount": null}
# Received answer: {"probability":0.0035473723986125917}
#
# Sending request...
# {"transactionId": 7474091076, "basket": null, "zipCode": 9754, "totalAmount": 474.0}
# Received answer: {"probability":0.002107031310366164}
#
# Sending request...
# {"transactionId": 6902563080, "basket": [2, 3, 1], "zipCode": 6727, "totalAmount": 216.0}
# Received answer: {"probability":0.008174452210510674}
#
# Sending request...
# {"transactionId": 2195175539, "basket": null, "zipCode": null, "totalAmount": 174.0}
# Received answer: {"probability":0.001965962976899683}
#
# Sending request...
# {"transactionId": 2008048466, "basket": null, "zipCode": 5310, "totalAmount": 704.0}
# Received answer: {"probability":0.0695390389096751}
#
# Sending request...
# {"transactionId": 5806718478, "basket": [4, 1, 1, 3, 2, 1, 4, 0, 3], "zipCode": 6497, "totalAmount": 90.0}
# Received answer: {"probability":0.06013207505177528}
#
# Sending request...
# {"transactionId": 5045324544, "basket": [1, 4], "zipCode": 6302, "totalAmount": 128.0}
# Received answer: {"probability":0.011150845502206092}
#
# Sending request...
# {"transactionId": 3044751619, "basket": [0, 2, 3, 2, 2], "zipCode": 5673, "totalAmount": null}
# Received answer: {"probability":0.011196174637367391}
#
# Sending request...
# {"transactionId": 3267978909, "basket": [3, 4, 0, 2, 1, 1, 4], "zipCode": 6577, "totalAmount": null}
# Received answer: {"probability":0.0009808532989639652}
#
# Sending request...
# {"transactionId": 5417769157, "basket": [0], "zipCode": 2795, "totalAmount": 46.0}
# Received answer: {"probability":0.09376929625861317}
#
# Sending request...
# {"transactionId": 3112007026, "basket": [1], "zipCode": 6771, "totalAmount": 70.0}
# Received answer: {"probability":0.004047898855757211}
#
# Sending request...
# {"transactionId": 5700295709, "basket": null, "zipCode": null, "totalAmount": 15.0}
# Received answer: {"probability":0.3386949028408774}
#
# Sending request...
# {"transactionId": 6471004303, "basket": [1, 4, 1, 4, 3], "zipCode": null, "totalAmount": 250.0}
# Received answer: {"probability":0.0178500523606007}
#
# Sending request...
# {"transactionId": 6281436619, "basket": [1, 0, 1, 4], "zipCode": 2214, "totalAmount": null}
# Received answer: {"probability":0.02514935975145354}
#
# Sending request...
# {"transactionId": 5887447471, "basket": [2], "zipCode": 7207, "totalAmount": 49.0}
# Received answer: {"probability":0.006490378054713306}
#
# Sending request...
# {"transactionId": 3691804349, "basket": [0, 0], "zipCode": 8749, "totalAmount": 60.0}
# Received answer: {"probability":0.018774421619669256}
#
# Sending request...
# {"transactionId": 4674619398, "basket": [1, 2, 2, 4], "zipCode": 7757, "totalAmount": 180.0}
# Received answer: {"probability":0.008018517779173239}
#
# Sending request...
# {"transactionId": 2412529139, "basket": null, "zipCode": 8366, "totalAmount": null}
# Received answer: {"probability":0.008644995274867272}
#
# Sending request...
# {"transactionId": 2364902127, "basket": [3, 3, 2, 2], "zipCode": 9171, "totalAmount": 264.0}
# Received answer: {"probability":0.04586453380054338}
#
# Sending request...
# {"transactionId": 3540717355, "basket": [0, 3, 3, 0, 0, 3], "zipCode": 4380, "totalAmount": 462.0}
# Received answer: {"probability":0.004951598232130865}
#
# Sending request...
# {"transactionId": 3192543002, "basket": [0], "zipCode": 5802, "totalAmount": 62.0}
# Received answer: {"probability":0.01504335806824521}
#
# Sending request...
# {"transactionId": 9961822918, "basket": null, "zipCode": 9614, "totalAmount": 38.0}
# Received answer: {"probability":0.007798079779687486}
#
# Sending request...
# {"transactionId": 8703203688, "basket": [4], "zipCode": 4197, "totalAmount": 117.0}
# Received answer: {"probability":0.06778048364367495}
#
# Sending request...
# {"transactionId": 5400894067, "basket": [3, 1], "zipCode": null, "totalAmount": 132.0}
# Received answer: {"probability":0.007176606660271883}
#
# Sending request...
# {"transactionId": 1323066579, "basket": [3, 2, 2, 4, 2], "zipCode": 7295, "totalAmount": 370.0}
# Received answer: {"probability":0.0007654477110134271}
#
# Sending request...
# {"transactionId": 6434181696, "basket": [3], "zipCode": 8301, "totalAmount": 68.0}
# Received answer: {"probability":0.0007583921738622693}
#
# Sending request...
# {"transactionId": 3485037495, "basket": [4, 1, 2, 0, 1, 0, 1, 3, 1, 3, 2, 2], "zipCode": 6396, "totalAmount": 300.0}
# Received answer: {"probability":0.0303992704964092}
#
# Sending request...
# {"transactionId": 8241114297, "basket": null, "zipCode": 8189, "totalAmount": 88.0}
# Received answer: {"probability":0.0018024033209382748}
#
# Sending request...
# {"transactionId": 7249788798, "basket": null, "zipCode": 6225, "totalAmount": 434.0}
# Received answer: {"probability":0.017286346383666697}
#
# Sending request...
# {"transactionId": 8087350091, "basket": [2, 3, 3], "zipCode": 8865, "totalAmount": 102.0}
# Received answer: {"probability":0.22447558479890536}
#
# Sending request...
# {"transactionId": 1681573266, "basket": [2], "zipCode": 4155, "totalAmount": 68.0}
# Received answer: {"probability":0.007479945522595102}
#
# Sending request...
# {"transactionId": 3841406603, "basket": [2, 4, 3, 2, 0, 2], "zipCode": 7360, "totalAmount": 222.0}
# Received answer: {"probability":0.007598054700265769}
#
# Sending request...
# {"transactionId": 7649221587, "basket": [1, 0, 3, 0, 2, 4, 2, 1], "zipCode": 5582, "totalAmount": 544.0}
# Received answer: {"probability":0.006588815754130633}
#
# Sending request...
# {"transactionId": 7990005377, "basket": [2, 1, 3, 1, 4, 3, 0], "zipCode": 9440, "totalAmount": 602.0}
# Received answer: {"probability":0.008564413352601557}
#
# Sending request...
# {"transactionId": 7378507606, "basket": null, "zipCode": 8715, "totalAmount": 272.0}
# Received answer: {"probability":0.0012169845467722654}
#
# Sending request...
# {"transactionId": 6081992543, "basket": null, "zipCode": null, "totalAmount": 102.0}
# Received answer: {"probability":0.007272167219435245}
#
# Sending request...
# {"transactionId": 3248108609, "basket": [4, 0, 4, 1, 1, 4, 1, 0], "zipCode": 3084, "totalAmount": 208.0}
# Received answer: {"probability":0.019118369171588795}
#
# Sending request...
# {"transactionId": 2989431484, "basket": [1, 3, 1, 4, 3], "zipCode": 9264, "totalAmount": 370.0}
# Received answer: {"probability":0.007044793944574188}
#
# Sending request...
# {"transactionId": 2591356123, "basket": null, "zipCode": 3749, "totalAmount": 324.0}
# Received answer: {"probability":0.0016407448102613092}
#
# Sending request...
# {"transactionId": 1973475161, "basket": [1, 3, 1, 0, 0, 1], "zipCode": 9060, "totalAmount": 336.0}
# Received answer: {"probability":0.007534617901387071}
#
# Sending request...
# {"transactionId": 7321708220, "basket": [3, 3, 0, 2, 3], "zipCode": 6366, "totalAmount": 315.0}
# Received answer: {"probability":0.002762325220067054}
#
# Sending request...
# {"transactionId": 9281543480, "basket": [0, 0, 4, 3, 0], "zipCode": 7452, "totalAmount": 100.0}
# Received answer: {"probability":0.25965107441146124}
#
# Sending request...
# {"transactionId": 9235800156, "basket": [2, 3, 1, 2, 3, 1, 1], "zipCode": 2909, "totalAmount": null}
# Received answer: {"probability":0.008745416250278882}
#
# Sending request...
# {"transactionId": 4307991963, "basket": [0, 0, 4, 0], "zipCode": 7435, "totalAmount": 208.0}
# Received answer: {"probability":0.08767252641793354}
#
# Sending request...
# {"transactionId": 8806479107, "basket": [3, 4, 2, 1, 3, 2], "zipCode": 6344, "totalAmount": null}
# Received answer: {"probability":0.14713905906963995}
#
# Sending request...
# {"transactionId": 9532406274, "basket": [0, 1, 0], "zipCode": 5833, "totalAmount": 231.0}
# Received answer: {"probability":0.007829794537784287}
#
# Sending request...
# {"transactionId": 6513605084, "basket": null, "zipCode": 9809, "totalAmount": null}
# Received answer: {"probability":0.0011765683596337956}
#
# Sending request...
# {"transactionId": 4111370349, "basket": [4, 0, 4, 4, 1], "zipCode": 5030, "totalAmount": 375.0}
# Received answer: {"probability":0.06065804365708034}
#
# Sending request...
# {"transactionId": 7069773719, "basket": [2, 4, 2, 4, 4, 4], "zipCode": 4607, "totalAmount": 90.0}
# Received answer: {"probability":0.014356711314607622}
#
# Sending request...
# {"transactionId": 5893067653, "basket": [0, 4, 0, 1, 1], "zipCode": 4254, "totalAmount": 310.0}
# Received answer: {"probability":0.018594928112236876}
#
# Sending request...
# {"transactionId": 5990754010, "basket": [2, 1, 1, 0, 3, 4, 1], "zipCode": 8827, "totalAmount": 462.0}
# Received answer: {"probability":0.004679724809098582}
#
# Sending request...
# {"transactionId": 6867805626, "basket": [3, 1, 1, 0, 2, 0], "zipCode": 4563, "totalAmount": 510.0}
# Received answer: {"probability":0.031934113620741264}
#
# Sending request...
# {"transactionId": 8189149581, "basket": [0, 4, 1, 4, 1, 0, 0, 4], "zipCode": null, "totalAmount": 640.0}
# Received answer: {"probability":0.00618483400012293}
#
# Sending request...
# {"transactionId": 8050802678, "basket": [2, 2, 0, 0, 4], "zipCode": 8110, "totalAmount": 605.0}
# Received answer: {"probability":0.007217174018742507}
#
# Sending request...
# {"transactionId": 7414791753, "basket": [1, 1, 1, 0, 4], "zipCode": 6150, "totalAmount": 50.0}
# Received answer: {"probability":0.024023126966746397}
#
# Sending request...
# {"transactionId": 7875048246, "basket": [3, 4], "zipCode": 9604, "totalAmount": 124.0}
# Received answer: {"probability":0.005230262180747254}
#
# Sending request...
# {"transactionId": 6490147362, "basket": [3, 1], "zipCode": 1499, "totalAmount": 20.0}
# Received answer: {"probability":0.0094949972531425}
#
# Sending request...
# {"transactionId": 2491090665, "basket": [2, 2, 4, 4, 3, 3, 4], "zipCode": 4087, "totalAmount": null}
# Received answer: {"probability":0.0007164985892985146}
#
# Sending request...
# {"transactionId": 1788487436, "basket": [2, 3, 4, 4, 0, 2, 3], "zipCode": null, "totalAmount": 175.0}
# Received answer: {"probability":0.002067964838747554}
#
# Sending request...
# {"transactionId": 5077604040, "basket": null, "zipCode": 5312, "totalAmount": 10.0}
# Received answer: {"probability":0.00011702018826510915}
#
# Sending request...
# {"transactionId": 3749096390, "basket": [3, 0, 0, 3, 2, 1, 1], "zipCode": 2600, "totalAmount": 252.0}
# Received answer: {"probability":0.00838916360985065}
#
# Sending request...
# {"transactionId": 8881400612, "basket": null, "zipCode": null, "totalAmount": 81.0}
# Received answer: {"probability":0.02257508416499489}
#
# Sending request...
# {"transactionId": 1129880266, "basket": null, "zipCode": 6159, "totalAmount": 90.0}
# Received answer: {"probability":0.0017315999274725583}
#
# Sending request...
# {"transactionId": 5256325895, "basket": [1, 4, 0, 4, 4, 1, 1, 4], "zipCode": 6851, "totalAmount": 472.0}
# Received answer: {"probability":0.007841823521031141}
#
# Sending request...
# {"transactionId": 6648903905, "basket": [0, 3, 1, 0, 0, 4, 3], "zipCode": 4437, "totalAmount": 483.0}
# Received answer: {"probability":0.01891216988808734}
#
# Sending request...
# {"transactionId": 8646452854, "basket": [1], "zipCode": 9303, "totalAmount": 71.0}
# Received answer: {"probability":0.007074303072579207}
#
# Sending request...
# {"transactionId": 1033129249, "basket": [0, 2, 2, 2, 2, 1], "zipCode": 5173, "totalAmount": 480.0}
# Received answer: {"probability":0.011341414209196968}
#
# Sending request...
# {"transactionId": 5649394958, "basket": [0, 0, 1, 1, 4, 1, 1], "zipCode": 1820, "totalAmount": 343.0}
# Received answer: {"probability":0.00021856771468089354}
#
# Sending request...
# {"transactionId": 7389237060, "basket": [2, 4, 0, 3], "zipCode": 4533, "totalAmount": null}
# Received answer: {"probability":0.061654369935351234}
#
# Sending request...
# {"transactionId": 6945565760, "basket": [1, 3, 3, 1, 4], "zipCode": 8046, "totalAmount": 70.0}
# Received answer: {"probability":0.008315835803572223}
#
# Sending request...
# {"transactionId": 5188326677, "basket": [2], "zipCode": 3326, "totalAmount": 81.0}
# Received answer: {"probability":0.0026476245096002074}
#
# Sending request...
# {"transactionId": 4419265538, "basket": [2, 1, 4, 1, 2, 4, 1, 3], "zipCode": 4535, "totalAmount": 408.0}
# Received answer: {"probability":0.0013336546708554084}
#
# Sending request...
# {"transactionId": 1587231376, "basket": [0, 2, 3, 1], "zipCode": 9533, "totalAmount": 132.0}
# Received answer: {"probability":8.219447246902044e-05}
#
# Sending request...
# {"transactionId": 4550119286, "basket": [4, 2, 3, 3, 0, 4], "zipCode": null, "totalAmount": 408.0}
# Received answer: {"probability":0.07483805916874478}
#
# Sending request...
# {"transactionId": 8039113806, "basket": null, "zipCode": 8637, "totalAmount": null}
# Received answer: {"probability":0.02445882596236722}
#
# Sending request...
# {"transactionId": 6628744785, "basket": [0, 0, 2, 1, 0, 4, 0], "zipCode": null, "totalAmount": 378.0}
# Received answer: {"probability":0.005300838406520729}
#
# Sending request...
# {"transactionId": 9001792874, "basket": [1], "zipCode": 9526, "totalAmount": 27.0}
# Received answer: {"probability":0.0021040085755707275}
#
# Sending request...
# {"transactionId": 8396763444, "basket": [1, 3, 0, 3, 1, 4], "zipCode": 9403, "totalAmount": 288.0}
# Received answer: {"probability":0.026020281989792022}
#
# Sending request...
# {"transactionId": 9020233412, "basket": [2, 1, 1, 4, 1, 2, 2, 4], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.003367196094278017}
#
# Sending request...
# {"transactionId": 8884897365, "basket": [4, 4, 4, 1, 3], "zipCode": 3543, "totalAmount": null}
# Received answer: {"probability":0.022794930022953293}
#
# Sending request...
# {"transactionId": 7836688417, "basket": [1, 0, 0, 1, 4, 0], "zipCode": null, "totalAmount": 60.0}
# Received answer: {"probability":0.020258851171080304}
#
# Sending request...
# {"transactionId": 7346091613, "basket": [0, 2, 4, 2, 3], "zipCode": 2072, "totalAmount": 585.0}
# Received answer: {"probability":0.01884723694732048}
#
# Sending request...
# {"transactionId": 7923096166, "basket": [2], "zipCode": 5740, "totalAmount": 41.0}
# Received answer: {"probability":0.16277135862321837}
#
# Sending request...
# {"transactionId": 5886424058, "basket": [0, 1, 3, 2, 0], "zipCode": 4241, "totalAmount": 180.0}
# Received answer: {"probability":0.00783268206651419}
#
# Sending request...
# {"transactionId": 2687984747, "basket": [2], "zipCode": 7056, "totalAmount": null}
# Received answer: {"probability":0.006746562002156508}
#
# Sending request...
# {"transactionId": 8357387277, "basket": [3, 3], "zipCode": 5364, "totalAmount": 78.0}
# Received answer: {"probability":0.004891209109161656}
#
# Sending request...
# {"transactionId": 6967783846, "basket": null, "zipCode": 1772, "totalAmount": 89.0}
# Received answer: {"probability":0.008580911656830456}
#
# Sending request...
# {"transactionId": 3279509406, "basket": [4, 2, 4], "zipCode": 2484, "totalAmount": null}
# Received answer: {"probability":0.0012945264586794482}
#
# Sending request...
# {"transactionId": 5324684874, "basket": [3, 2, 3, 3, 1], "zipCode": 4419, "totalAmount": 530.0}
# Received answer: {"probability":0.006158038620089041}
#
# Sending request...
# {"transactionId": 9166675144, "basket": [3, 0, 0, 4, 4, 4, 2], "zipCode": 9261, "totalAmount": 371.0}
# Received answer: {"probability":0.13656443904327373}
#
# Sending request...
# {"transactionId": 7336435152, "basket": null, "zipCode": 1326, "totalAmount": null}
# Received answer: {"probability":0.051267820976095224}
#
# Sending request...
# {"transactionId": 3922949843, "basket": [1, 1], "zipCode": 1975, "totalAmount": 36.0}
# Received answer: {"probability":0.03792761381026181}
#
# Sending request...
# {"transactionId": 7682978464, "basket": [4, 4, 2, 1, 3, 3, 3, 0, 0, 0, 4], "zipCode": 4477, "totalAmount": 572.0}
# Received answer: {"probability":0.012330167038659629}
#
# Sending request...
# {"transactionId": 2844998946, "basket": [4, 1, 4, 3, 0], "zipCode": 8163, "totalAmount": null}
# Received answer: {"probability":0.00034065089762673966}
#
# Sending request...
# {"transactionId": 1265285941, "basket": null, "zipCode": null, "totalAmount": 43.0}
# Received answer: {"probability":0.0011125429628231886}
#
# Sending request...
# {"transactionId": 4395253452, "basket": [0, 2, 3, 4, 0, 2], "zipCode": null, "totalAmount": 78.0}
# Received answer: {"probability":0.026528253669859177}
#
# Sending request...
# {"transactionId": 4502635796, "basket": [1, 4], "zipCode": 4922, "totalAmount": 90.0}
# Received answer: {"probability":0.034765564261596035}
#
# Sending request...
# {"transactionId": 1853311839, "basket": [1, 2, 3, 3, 0, 4, 1, 4, 0], "zipCode": null, "totalAmount": 450.0}
# Received answer: {"probability":0.011116121069888758}
#
# Sending request...
# {"transactionId": 2455022336, "basket": null, "zipCode": 3288, "totalAmount": 198.0}
# Received answer: {"probability":0.0039897658969388315}
#
# Sending request...
# {"transactionId": 1309883584, "basket": [2, 3, 1, 0, 4], "zipCode": 8206, "totalAmount": 205.0}
# Received answer: {"probability":0.005709392916729737}
#
# Sending request...
# {"transactionId": 9262012225, "basket": [3, 4, 1], "zipCode": 3655, "totalAmount": null}
# Received answer: {"probability":0.007515859645868844}
#
# Sending request...
# {"transactionId": 6277524854, "basket": null, "zipCode": 1480, "totalAmount": 264.0}
# Received answer: {"probability":0.006700164462179247}
#
# Sending request...
# {"transactionId": 6501035930, "basket": [3], "zipCode": 3957, "totalAmount": 91.0}
# Received answer: {"probability":0.002697333863276721}
#
# Sending request...
# {"transactionId": 4808024545, "basket": [4, 4, 4, 2, 1], "zipCode": 2518, "totalAmount": null}
# Received answer: {"probability":0.002814398658196291}
#
# Sending request...
# {"transactionId": 9490146189, "basket": [3, 1, 3, 3], "zipCode": 9397, "totalAmount": 40.0}
# Received answer: {"probability":0.03739234845392277}
#
# Sending request...
# {"transactionId": 5736806365, "basket": [4, 3], "zipCode": 6546, "totalAmount": 20.0}
# Received answer: {"probability":0.009482968479966816}
#
# Sending request...
# {"transactionId": 6201613133, "basket": [1, 4, 3, 4, 2, 0, 3, 4, 0], "zipCode": 4499, "totalAmount": 90.0}
# Received answer: {"probability":0.008126948055325291}
#
# Sending request...
# {"transactionId": 9721917364, "basket": [0, 2, 4, 4], "zipCode": 6872, "totalAmount": 184.0}
# Received answer: {"probability":0.0020622856106998536}
#
# Sending request...
# {"transactionId": 3153006451, "basket": [3, 0, 2, 2, 4], "zipCode": 5393, "totalAmount": 50.0}
# Received answer: {"probability":0.013511723061500893}
#
# Sending request...
# {"transactionId": 7506733720, "basket": [0, 2, 2, 0], "zipCode": 5472, "totalAmount": null}
# Received answer: {"probability":0.015872430218543336}
#
# Sending request...
# {"transactionId": 2116527369, "basket": [4, 1, 2], "zipCode": 1421, "totalAmount": 153.0}
# Received answer: {"probability":0.0096068600027571}
#
# Sending request...
# {"transactionId": 5384170932, "basket": [4, 1, 1, 1, 1], "zipCode": 5789, "totalAmount": 330.0}
# Received answer: {"probability":0.00807469825963684}
#
# Sending request...
# {"transactionId": 5704182597, "basket": null, "zipCode": 3120, "totalAmount": 80.0}
# Received answer: {"probability":0.012372283694962335}
#
# Sending request...
# {"transactionId": 9644446362, "basket": [3, 3, 1, 1], "zipCode": 6002, "totalAmount": 288.0}
# Received answer: {"probability":0.003046397702096184}
#
# Sending request...
# {"transactionId": 5526544525, "basket": [4, 4], "zipCode": 4164, "totalAmount": 88.0}
# Received answer: {"probability":0.007601334423934671}
#
# Sending request...
# {"transactionId": 5734580055, "basket": [4, 2, 2, 3, 2, 4], "zipCode": 9011, "totalAmount": 426.0}
# Received answer: {"probability":0.006500507366036506}
#
# Sending request...
# {"transactionId": 1663761926, "basket": [4, 0, 3], "zipCode": 7039, "totalAmount": null}
# Received answer: {"probability":0.017169767346210868}
#
# Sending request...
# {"transactionId": 4225013618, "basket": [2], "zipCode": 6784, "totalAmount": 10.0}
# Received answer: {"probability":0.007008659691737007}
#
# Sending request...
# {"transactionId": 1511042267, "basket": [3, 1, 3, 4], "zipCode": 3386, "totalAmount": 232.0}
# Received answer: {"probability":0.005830861187788209}
#
# Sending request...
# {"transactionId": 4410249504, "basket": null, "zipCode": null, "totalAmount": 204.0}
# Received answer: {"probability":0.005431144945055533}
#
# Sending request...
# {"transactionId": 4161889222, "basket": null, "zipCode": 1047, "totalAmount": 504.0}
# Received answer: {"probability":0.009111664577082856}
#
# Sending request...
# {"transactionId": 6919219575, "basket": [4], "zipCode": 7179, "totalAmount": 57.0}
# Received answer: {"probability":0.010106429343919381}
#
# Sending request...
# {"transactionId": 7908325821, "basket": [4], "zipCode": 1287, "totalAmount": 96.0}
# Received answer: {"probability":0.005467304918336208}
#
# Sending request...
# {"transactionId": 3675418971, "basket": [3, 3, 4, 1], "zipCode": null, "totalAmount": 248.0}
# Received answer: {"probability":0.0008392369816548257}
#
# Sending request...
# {"transactionId": 7642599080, "basket": [1, 2, 0, 3, 2, 1], "zipCode": 4185, "totalAmount": null}
# Received answer: {"probability":0.012325422875086837}
#
# Sending request...
# {"transactionId": 3522244991, "basket": [4], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.007989076554556608}
#
# Sending request...
# {"transactionId": 8615941773, "basket": [2, 4, 0, 3, 1], "zipCode": 3395, "totalAmount": null}
# Received answer: {"probability":0.0005652208987587904}
#
# Sending request...
# {"transactionId": 1512135503, "basket": null, "zipCode": 8640, "totalAmount": 23.0}
# Received answer: {"probability":0.011046627802234149}
#
# Sending request...
# {"transactionId": 7505335932, "basket": [3, 4, 2, 2, 3], "zipCode": null, "totalAmount": 310.0}
# Received answer: {"probability":0.001953377128459431}
#
# Sending request...
# {"transactionId": 2071912769, "basket": null, "zipCode": 3373, "totalAmount": 144.0}
# Received answer: {"probability":0.008063015201037244}
#
# Sending request...
# {"transactionId": 2942964811, "basket": [4, 3, 4, 4], "zipCode": 1094, "totalAmount": null}
# Received answer: {"probability":0.0002447621909136005}
#
# Sending request...
# {"transactionId": 7988151529, "basket": [4, 0, 1, 1, 4], "zipCode": 4074, "totalAmount": 405.0}
# Received answer: {"probability":0.0006396633522458643}
#
# Sending request...
# {"transactionId": 1338031509, "basket": [2, 3], "zipCode": 4921, "totalAmount": null}
# Received answer: {"probability":0.005798146991923943}
#
# Sending request...
# {"transactionId": 4628373751, "basket": [1, 0, 1, 2, 1, 2, 2], "zipCode": 2326, "totalAmount": null}
# Received answer: {"probability":0.009546342391318716}
#
# Sending request...
# {"transactionId": 3219548587, "basket": [4, 2, 1], "zipCode": 1418, "totalAmount": null}
# Received answer: {"probability":0.015581343655011758}
#
# Sending request...
# {"transactionId": 2977785066, "basket": null, "zipCode": 6705, "totalAmount": 204.0}
# Received answer: {"probability":0.013522229178124344}
#
# Sending request...
# {"transactionId": 8771722222, "basket": [1, 1, 3, 3, 4], "zipCode": 4688, "totalAmount": 190.0}
# Received answer: {"probability":0.0002944265076688795}
#
# Sending request...
# {"transactionId": 8926251354, "basket": [0, 2, 4, 2, 2], "zipCode": 5878, "totalAmount": 80.0}
# Received answer: {"probability":0.005242556159159358}
#
# Sending request...
# {"transactionId": 9607571152, "basket": [3, 2], "zipCode": 2059, "totalAmount": 52.0}
# Received answer: {"probability":0.007405797858839052}
#
# Sending request...
# {"transactionId": 7514003851, "basket": [3, 0, 2, 0, 0], "zipCode": 4946, "totalAmount": 240.0}
# Received answer: {"probability":0.047228448662045966}
#
# Sending request...
# {"transactionId": 2206392639, "basket": [2], "zipCode": 1273, "totalAmount": 10.0}
# Received answer: {"probability":0.0028428876423116024}
#
# Sending request...
# {"transactionId": 8984601582, "basket": null, "zipCode": 7331, "totalAmount": 36.0}
# Received answer: {"probability":0.008461286902467826}
#
# Sending request...
# {"transactionId": 2877173298, "basket": [2, 3, 1, 0, 4, 3, 3, 2, 4, 1], "zipCode": 3050, "totalAmount": 190.0}
# Received answer: {"probability":0.018106374014756774}
#
# Sending request...
# {"transactionId": 5193209857, "basket": [1, 3, 4, 2, 3, 2], "zipCode": 3212, "totalAmount": 252.0}
# Received answer: {"probability":0.007136150180846799}
#
# Sending request...
# {"transactionId": 7310533682, "basket": [0, 2, 3], "zipCode": 4535, "totalAmount": 159.0}
# Received answer: {"probability":0.008690464917608158}
#
# Sending request...
# {"transactionId": 7143372199, "basket": [2, 4, 1, 4], "zipCode": 9266, "totalAmount": 116.0}
# Received answer: {"probability":0.004593244109427396}
#
# Sending request...
# {"transactionId": 9723816940, "basket": null, "zipCode": 7463, "totalAmount": 198.0}
# Received answer: {"probability":0.017412970744004247}
#
# Sending request...
# {"transactionId": 2164025209, "basket": [3, 0, 0], "zipCode": 8586, "totalAmount": 48.0}
# Received answer: {"probability":0.02518604751650299}
#
# Sending request...
# {"transactionId": 8934946928, "basket": [1, 1, 4, 2], "zipCode": 4569, "totalAmount": 356.0}
# Received answer: {"probability":0.00312733822098046}
#
# Sending request...
# {"transactionId": 7448624515, "basket": null, "zipCode": 1887, "totalAmount": 260.0}
# Received answer: {"probability":0.008206392405788063}
#
# Sending request...
# {"transactionId": 3190038741, "basket": [4], "zipCode": 3919, "totalAmount": 73.0}
# Received answer: {"probability":0.03482832318988633}
#
# Sending request...
# {"transactionId": 1050076553, "basket": [3, 4, 0, 3, 1], "zipCode": 1811, "totalAmount": 50.0}
# Received answer: {"probability":0.006406254645693639}
#
# Sending request...
# {"transactionId": 9426757035, "basket": null, "zipCode": 3434, "totalAmount": 30.0}
# Received answer: {"probability":0.001711249612877001}
#
# Sending request...
# {"transactionId": 2173747973, "basket": [1, 0], "zipCode": 2708, "totalAmount": 20.0}
# Received answer: {"probability":0.008774850461333921}
#
# Sending request...
# {"transactionId": 5376101917, "basket": [2, 0, 3, 4, 2], "zipCode": 9699, "totalAmount": 355.0}
# Received answer: {"probability":0.018534284782620994}
#
# Sending request...
# {"transactionId": 7525746031, "basket": [1, 2, 2, 3, 3, 1, 0, 4, 3, 4, 0], "zipCode": null, "totalAmount": 506.0}
# Received answer: {"probability":0.0368740351089137}
#
# Sending request...
# {"transactionId": 8695857441, "basket": [3, 4, 3, 4, 1, 3, 0], "zipCode": null, "totalAmount": 931.0}
# Received answer: {"probability":0.0022808175636550403}
#
# Sending request...
# {"transactionId": 6007676148, "basket": [4, 0, 1, 4], "zipCode": null, "totalAmount": 396.0}
# Received answer: {"probability":0.008306369224992975}
#
# Sending request...
# {"transactionId": 4424371575, "basket": [1, 2, 1], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.005126509553980503}
#
# Sending request...
# {"transactionId": 6053513201, "basket": [3, 1, 3, 2, 2, 2, 3, 0, 4], "zipCode": 4947, "totalAmount": 666.0}
# Received answer: {"probability":0.006416819592146454}
#
# Sending request...
# {"transactionId": 8946234075, "basket": null, "zipCode": 5153, "totalAmount": 588.0}
# Received answer: {"probability":0.023020987628478682}
#
# Sending request...
# {"transactionId": 5044653888, "basket": null, "zipCode": 5272, "totalAmount": 70.0}
# Received answer: {"probability":0.1973278404569997}
#
# Sending request...
# {"transactionId": 7030245709, "basket": [1, 2, 1, 4, 0, 0, 0, 1], "zipCode": 6433, "totalAmount": 416.0}
# Received answer: {"probability":0.024653010296099773}
#
# Sending request...
# {"transactionId": 3805746209, "basket": [4], "zipCode": 9081, "totalAmount": 44.0}
# Received answer: {"probability":0.021890885099805413}
#
# Sending request...
# {"transactionId": 8137004854, "basket": [2, 2, 1, 0, 4, 0, 4], "zipCode": 4440, "totalAmount": 511.0}
# Received answer: {"probability":0.005689877583410586}
#
# Sending request...
# {"transactionId": 9982697472, "basket": [0, 4], "zipCode": 9561, "totalAmount": 100.0}
# Received answer: {"probability":0.007298602747538688}
#
# Sending request...
# {"transactionId": 5417056109, "basket": [2, 2, 1, 1, 0], "zipCode": 1462, "totalAmount": 390.0}
# Received answer: {"probability":0.008916707759060012}
#
# Sending request...
# {"transactionId": 7047088766, "basket": [2], "zipCode": 7926, "totalAmount": 55.0}
# Received answer: {"probability":0.12456147275146347}
#
# Sending request...
# {"transactionId": 6771170194, "basket": [1], "zipCode": 4756, "totalAmount": 26.0}
# Received answer: {"probability":0.008680803394338119}
#
# Sending request...
# {"transactionId": 9538403953, "basket": null, "zipCode": 8922, "totalAmount": 10.0}
# Received answer: {"probability":0.01611207020775329}
#
# Sending request...
# {"transactionId": 3279600720, "basket": [3, 0], "zipCode": 6527, "totalAmount": 170.0}
# Received answer: {"probability":0.012835691996692898}
#
# Sending request...
# {"transactionId": 4563993139, "basket": null, "zipCode": 2937, "totalAmount": null}
# Received answer: {"probability":0.007800895303272175}
#
# Sending request...
# {"transactionId": 4113885781, "basket": [1, 3, 3], "zipCode": 6716, "totalAmount": 183.0}
# Received answer: {"probability":0.07343438574814909}
#
# Sending request...
# {"transactionId": 6260664810, "basket": [0, 3, 3, 3, 3, 3, 0], "zipCode": 9302, "totalAmount": 630.0}
# Received answer: {"probability":0.011793653831227251}
#
# Sending request...
# {"transactionId": 2339966406, "basket": [2, 4, 0, 4], "zipCode": null, "totalAmount": 84.0}
# Received answer: {"probability":0.0009821813057842833}
#
# Sending request...
# {"transactionId": 9905150292, "basket": [4, 0, 3, 2, 3], "zipCode": 8490, "totalAmount": 350.0}
# Received answer: {"probability":0.005663919124325932}
#
# Sending request...
# {"transactionId": 9728439704, "basket": [0, 4, 4, 0, 2, 0, 2, 3, 2], "zipCode": 7655, "totalAmount": null}
# Received answer: {"probability":0.018808407354378696}
#
# Sending request...
# {"transactionId": 2738443941, "basket": [1, 3, 4, 4, 2, 0], "zipCode": 4425, "totalAmount": 534.0}
# Received answer: {"probability":0.0013527894220739618}
#
# Sending request...
# {"transactionId": 6632646746, "basket": [1, 2], "zipCode": null, "totalAmount": 56.0}
# Received answer: {"probability":0.006013443813229562}
#
# Sending request...
# {"transactionId": 5302731114, "basket": [4, 3], "zipCode": 7318, "totalAmount": 20.0}
# Received answer: {"probability":0.04760542618001154}
#
# Sending request...
# {"transactionId": 4043704760, "basket": null, "zipCode": 5803, "totalAmount": 259.0}
# Received answer: {"probability":0.008329939210842522}
#
# Sending request...
# {"transactionId": 3392395915, "basket": [2, 2, 1, 4, 3, 4], "zipCode": 6482, "totalAmount": 186.0}
# Received answer: {"probability":0.10058049780108211}
#
# Sending request...
# {"transactionId": 5097752265, "basket": [0], "zipCode": 9918, "totalAmount": 79.0}
# Received answer: {"probability":0.007573616261431658}
#
# Sending request...
# {"transactionId": 5605004805, "basket": [1, 2, 4, 4, 3, 4], "zipCode": 2462, "totalAmount": null}
# Received answer: {"probability":0.07748945275804472}
#
# Sending request...
# {"transactionId": 1951078628, "basket": [3, 3, 3, 4, 0, 2], "zipCode": 9540, "totalAmount": 252.0}
# Received answer: {"probability":0.0074997362931617335}
#
# Sending request...
# {"transactionId": 7001747214, "basket": [0, 0, 1, 2, 4, 2, 4, 4, 0, 0], "zipCode": 2721, "totalAmount": 100.0}
# Received answer: {"probability":0.01945790667974717}
#
# Sending request...
# {"transactionId": 7655647116, "basket": null, "zipCode": null, "totalAmount": 592.0}
# Received answer: {"probability":0.08446121338903664}
#
# Sending request...
# {"transactionId": 2467149034, "basket": [0, 2, 1, 0, 2, 4, 0, 3], "zipCode": 6843, "totalAmount": 160.0}
# Received answer: {"probability":0.04830733405512435}
#
# Sending request...
# {"transactionId": 5444486067, "basket": [0], "zipCode": 9068, "totalAmount": null}
# Received answer: {"probability":0.004364771999857509}
#
# Sending request...
# {"transactionId": 2258969654, "basket": null, "zipCode": 8195, "totalAmount": null}
# Received answer: {"probability":0.12877704921290287}
#
# Sending request...
# {"transactionId": 5866566676, "basket": [1, 4, 2, 2, 0, 4], "zipCode": 4120, "totalAmount": null}
# Received answer: {"probability":0.014079208439673885}
#
# Sending request...
# {"transactionId": 6714397437, "basket": [0, 0], "zipCode": 3449, "totalAmount": 118.0}
# Received answer: {"probability":0.017588174779094905}
#
# Sending request...
# {"transactionId": 1705733354, "basket": [1, 1, 1, 3, 1, 0, 3], "zipCode": 5550, "totalAmount": 371.0}
# Received answer: {"probability":0.0014875309748806052}
#
# Sending request...
# {"transactionId": 7254186492, "basket": [4], "zipCode": 6639, "totalAmount": 62.0}
# Received answer: {"probability":0.0006955734199328493}
#
# Sending request...
# {"transactionId": 7275049086, "basket": [2, 1, 1, 2, 2, 3, 4, 4, 2, 4, 3, 1], "zipCode": 3077, "totalAmount": 348.0}
# Received answer: {"probability":0.0014342777137900087}
#
# Sending request...
# {"transactionId": 9752549021, "basket": [3, 2, 2, 2, 4, 3], "zipCode": null, "totalAmount": 168.0}
# Received answer: {"probability":0.04440542227569141}
#
# Sending request...
# {"transactionId": 6732434287, "basket": [2, 4, 0, 1, 2, 1], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.0023036828677763495}
#
# Sending request...
# {"transactionId": 7586278667, "basket": [0, 2, 1, 1, 3, 0, 3], "zipCode": 3661, "totalAmount": 147.0}
# Received answer: {"probability":0.00973094997042742}
#
# Sending request...
# {"transactionId": 2921685131, "basket": null, "zipCode": 7691, "totalAmount": 69.0}
# Received answer: {"probability":0.0694361632133743}
#
# Sending request...
# {"transactionId": 9037791687, "basket": [2], "zipCode": 8871, "totalAmount": 10.0}
# Received answer: {"probability":0.007027127663034034}
#
# Sending request...
# {"transactionId": 8916967953, "basket": [1, 4, 0, 0, 3, 4], "zipCode": 2107, "totalAmount": 168.0}
# Received answer: {"probability":0.008535170404875673}
#
# Sending request...
# {"transactionId": 2556239169, "basket": [3, 0, 0, 4, 3, 1], "zipCode": 5209, "totalAmount": 60.0}
# Received answer: {"probability":0.013287744929713827}
#
# Sending request...
# {"transactionId": 3943251635, "basket": null, "zipCode": 2831, "totalAmount": 312.0}
# Received answer: {"probability":0.009394504906653582}
#
# Sending request...
# {"transactionId": 7728895780, "basket": [2], "zipCode": 2109, "totalAmount": 134.0}
# Received answer: {"probability":0.003815149826420043}
#
# Sending request...
# {"transactionId": 8036462415, "basket": [1], "zipCode": 4045, "totalAmount": 48.0}
# Received answer: {"probability":0.0006313340798996931}
#
# Sending request...
# {"transactionId": 9660022575, "basket": [4, 1, 2, 1], "zipCode": 1297, "totalAmount": 96.0}
# Received answer: {"probability":0.0009159896698863918}
#
# Sending request...
# {"transactionId": 3326511267, "basket": null, "zipCode": 3365, "totalAmount": 188.0}
# Received answer: {"probability":0.01872543541018998}
#
# Sending request...
# {"transactionId": 4768152856, "basket": [2, 0, 4, 3, 4, 3], "zipCode": 9940, "totalAmount": 456.0}
# Received answer: {"probability":0.0099307336029458}
#
# Sending request...
# {"transactionId": 3649727186, "basket": [2, 0, 1, 0], "zipCode": 1426, "totalAmount": 344.0}
# Received answer: {"probability":0.03214117107577963}
#
# Sending request...
# {"transactionId": 1010872650, "basket": [2, 1, 2, 1, 4, 1, 0, 4, 3], "zipCode": 9236, "totalAmount": 351.0}
# Received answer: {"probability":0.0004792399805960265}
#
# Sending request...
# {"transactionId": 6340078548, "basket": [3, 0], "zipCode": 4646, "totalAmount": 70.0}
# Received answer: {"probability":0.009294950650807234}
#
# Sending request...
# {"transactionId": 6294740809, "basket": [1], "zipCode": 6922, "totalAmount": 52.0}
# Received answer: {"probability":0.038172540098925}
#
# Sending request...
# {"transactionId": 3963708495, "basket": null, "zipCode": null, "totalAmount": 80.0}
# Received answer: {"probability":0.0054642934671632545}
#
# Sending request...
# {"transactionId": 8268259306, "basket": [1], "zipCode": 8866, "totalAmount": 30.0}
# Received answer: {"probability":0.006909958356307606}
#
# Sending request...
# {"transactionId": 2280357949, "basket": [1, 4, 0, 3, 2, 1], "zipCode": null, "totalAmount": 288.0}
# Received answer: {"probability":0.03887470889682148}
#
# Sending request...
# {"transactionId": 7222261899, "basket": [0, 3, 4, 3, 1, 4, 0], "zipCode": 7730, "totalAmount": 609.0}
# Received answer: {"probability":0.013091226125705173}
#
# Sending request...
# {"transactionId": 7705009749, "basket": [3], "zipCode": 6453, "totalAmount": 22.0}
# Received answer: {"probability":0.027602118710211104}
#
# Sending request...
# {"transactionId": 3293381318, "basket": [0, 4], "zipCode": null, "totalAmount": 74.0}
# Received answer: {"probability":0.0030790164080192633}
#
# Sending request...
# {"transactionId": 7502481484, "basket": null, "zipCode": 3265, "totalAmount": 140.0}
# Received answer: {"probability":0.0014847839476377655}
#
# Sending request...
# {"transactionId": 9829596403, "basket": [2, 2, 2, 1, 3, 2], "zipCode": 9889, "totalAmount": 312.0}
# Received answer: {"probability":0.00031597141534864194}
#
# Sending request...
# {"transactionId": 6652983338, "basket": [1, 1, 1, 0, 4, 2], "zipCode": 3116, "totalAmount": 60.0}
# Received answer: {"probability":0.032645153722946296}
#
# Sending request...
# {"transactionId": 5219760257, "basket": [0, 4, 1, 0, 0], "zipCode": null, "totalAmount": 265.0}
# Received answer: {"probability":0.0013438875341135696}
#
# Sending request...
# {"transactionId": 6855421353, "basket": [0, 4, 2, 0], "zipCode": 1060, "totalAmount": 364.0}
# Received answer: {"probability":0.010527037694488262}
#
# Sending request...
# {"transactionId": 7369156067, "basket": [2, 0, 3, 0, 0], "zipCode": null, "totalAmount": 280.0}
# Received answer: {"probability":0.0011937523352179547}
#
# Sending request...
# {"transactionId": 2740275280, "basket": null, "zipCode": 7649, "totalAmount": 10.0}
# Received answer: {"probability":0.0049073429379532}
#
# Sending request...
# {"transactionId": 3164330933, "basket": [4, 3, 4, 1, 4], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.012163884982144131}
#
# Sending request...
# {"transactionId": 9319348410, "basket": [2, 4, 0, 3, 3, 1, 2], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.006478508789508239}
#
# Sending request...
# {"transactionId": 5731971514, "basket": [0, 4, 0, 3], "zipCode": 3243, "totalAmount": 100.0}
# Received answer: {"probability":0.003035267465044265}
#
# Sending request...
# {"transactionId": 4258994818, "basket": [3, 1, 3, 1, 0, 1, 3, 0], "zipCode": 7937, "totalAmount": 80.0}
# Received answer: {"probability":0.006042076686336871}
#
# Sending request...
# {"transactionId": 4845231496, "basket": [2, 3, 3, 4], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.03866863576244401}
#
# Sending request...
# {"transactionId": 4380759910, "basket": [0, 4, 2, 2, 1, 4, 2, 2], "zipCode": 2622, "totalAmount": 504.0}
# Received answer: {"probability":0.0022085331702378012}
#
# Sending request...
# {"transactionId": 7179291850, "basket": null, "zipCode": null, "totalAmount": 23.0}
# Received answer: {"probability":0.0026891793705867643}
#
# Sending request...
# {"transactionId": 1074373639, "basket": [3, 0, 0, 3, 4, 3, 0, 3, 1, 2, 1], "zipCode": null, "totalAmount": 341.0}
# Received answer: {"probability":0.018415217782172755}
#
# Sending request...
# {"transactionId": 7315264254, "basket": [4, 1, 0, 0, 3, 4, 3], "zipCode": 4126, "totalAmount": 336.0}
# Received answer: {"probability":0.0005090139712438114}
#
# Sending request...
# {"transactionId": 5163268529, "basket": [3, 2, 4, 3], "zipCode": 4881, "totalAmount": 320.0}
# Received answer: {"probability":0.01680330187720687}
#
# Sending request...
# {"transactionId": 8785259566, "basket": [0], "zipCode": null, "totalAmount": 74.0}
# Received answer: {"probability":0.012313454586036512}
#
# Sending request...
# {"transactionId": 5543885662, "basket": [1, 1, 1], "zipCode": null, "totalAmount": 168.0}
# Received answer: {"probability":0.005456359172226659}
#
# Sending request...
# {"transactionId": 5053529954, "basket": [3], "zipCode": 8353, "totalAmount": 80.0}
# Received answer: {"probability":0.022657388721749983}
#
# Sending request...
# {"transactionId": 5272116231, "basket": [2, 1, 1], "zipCode": 4523, "totalAmount": 243.0}
# Received answer: {"probability":0.011145202674973315}
#
# Sending request...
# {"transactionId": 8959163504, "basket": [4, 4, 1, 1, 3, 4, 0, 2, 3, 2, 1], "zipCode": 8234, "totalAmount": 660.0}
# Received answer: {"probability":0.004469873612445126}
#
# Sending request...
# {"transactionId": 9595076611, "basket": [0, 0, 1, 3, 2, 0, 0], "zipCode": null, "totalAmount": 623.0}
# Received answer: {"probability":0.008054712690991037}
#
# Sending request...
# {"transactionId": 2897701822, "basket": [2, 0, 2, 0, 3, 0, 2, 1], "zipCode": 9744, "totalAmount": null}
# Received answer: {"probability":0.007794524519886673}
#
# Sending request...
# {"transactionId": 5458908707, "basket": null, "zipCode": null, "totalAmount": 567.0}
# Received answer: {"probability":0.008174452210510674}
#
# Sending request...
# {"transactionId": 7328643043, "basket": [3, 2, 0, 0, 0], "zipCode": 2957, "totalAmount": 155.0}
# Received answer: {"probability":0.0033125995046195157}
#
# Sending request...
# {"transactionId": 5423786727, "basket": [3, 1, 1], "zipCode": 1059, "totalAmount": 117.0}
# Received answer: {"probability":0.008577982482741059}
#
# Sending request...
# {"transactionId": 3839975430, "basket": null, "zipCode": 1358, "totalAmount": 30.0}
# Received answer: {"probability":0.0029199970342221417}
#
# Sending request...
# {"transactionId": 1767975336, "basket": [4], "zipCode": null, "totalAmount": 97.0}
# Received answer: {"probability":0.019020105498643775}
#
# Sending request...
# {"transactionId": 8833776583, "basket": [3], "zipCode": 1599, "totalAmount": 51.0}
# Received answer: {"probability":0.03844588401102274}
#
# Sending request...
# {"transactionId": 3554768098, "basket": null, "zipCode": 2673, "totalAmount": 40.0}
# Received answer: {"probability":0.015626076758939362}
#
# Sending request...
# {"transactionId": 1452709571, "basket": [2, 2, 4, 2], "zipCode": 2787, "totalAmount": 268.0}
# Received answer: {"probability":0.045925795215039575}
#
# Sending request...
# {"transactionId": 8947032239, "basket": [2], "zipCode": 3289, "totalAmount": 10.0}
# Received answer: {"probability":0.009643999993831831}
#
# Sending request...
# {"transactionId": 9616757553, "basket": [0, 0, 1, 1, 1], "zipCode": null, "totalAmount": 230.0}
# Received answer: {"probability":0.006144559677753331}
#
# Sending request...
# {"transactionId": 5554087776, "basket": [1, 2, 3, 2, 0, 4], "zipCode": 2546, "totalAmount": 564.0}
# Received answer: {"probability":0.004662663201928205}
#
# Sending request...
# {"transactionId": 7854389269, "basket": [3, 0, 4, 3, 1, 3, 3, 1], "zipCode": 5057, "totalAmount": 528.0}
# Received answer: {"probability":0.007675398182658366}
#
# Sending request...
# {"transactionId": 4748558962, "basket": [3, 4, 0], "zipCode": 6085, "totalAmount": null}
# Received answer: {"probability":0.0027120343588910886}
#
# Sending request...
# {"transactionId": 2657979623, "basket": [4, 0, 1, 4, 4, 4, 4], "zipCode": 4641, "totalAmount": 140.0}
# Received answer: {"probability":0.0050399127395085635}
#
# Sending request...
# {"transactionId": 1004321148, "basket": [2, 4, 0, 4], "zipCode": null, "totalAmount": 332.0}
# Received answer: {"probability":0.02423574278336974}
#
# Sending request...
# {"transactionId": 6694894584, "basket": null, "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.0377428992326433}
#
# Sending request...
# {"transactionId": 8583301343, "basket": [1, 3, 1, 2], "zipCode": 2199, "totalAmount": 320.0}
# Received answer: {"probability":0.008529613750538798}
#
# Sending request...
# {"transactionId": 9419462130, "basket": [1, 2, 0, 1, 1, 2, 1], "zipCode": 2882, "totalAmount": 70.0}
# Received answer: {"probability":0.008154601745693487}
#
# Sending request...
# {"transactionId": 8506135658, "basket": [1, 3], "zipCode": 5853, "totalAmount": 96.0}
# Received answer: {"probability":0.0026786942455176497}
#
# Sending request...
# {"transactionId": 2750148986, "basket": [3, 0, 0, 4, 2], "zipCode": 8499, "totalAmount": 260.0}
# Received answer: {"probability":0.12945514645557485}
#
# Sending request...
# {"transactionId": 3202693750, "basket": [3, 4, 4, 1, 1, 1, 1, 4, 1], "zipCode": 4982, "totalAmount": 711.0}
# Received answer: {"probability":0.012508346743294372}
#
# Sending request...
# {"transactionId": 5341124637, "basket": [1, 4, 2, 3, 4, 3, 1, 0, 0], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.0072796808029887946}
#
# Sending request...
# {"transactionId": 4628206144, "basket": null, "zipCode": null, "totalAmount": 726.0}
# Received answer: {"probability":0.0067932502500372555}
#
# Sending request...
# {"transactionId": 8333873275, "basket": null, "zipCode": 9679, "totalAmount": 275.0}
# Received answer: {"probability":0.0027230146097783677}
#
# Sending request...
# {"transactionId": 6438622921, "basket": [3, 3, 4, 3, 3, 2, 1], "zipCode": 7335, "totalAmount": null}
# Received answer: {"probability":0.0014341985710813738}
#
# Sending request...
# {"transactionId": 1968163499, "basket": null, "zipCode": 6908, "totalAmount": 475.0}
# Received answer: {"probability":0.0022173743323706738}
#
# Sending request...
# {"transactionId": 8275275899, "basket": [2, 4], "zipCode": 3298, "totalAmount": 146.0}
# Received answer: {"probability":0.011133553664294684}
#
# Sending request...
# {"transactionId": 8329161907, "basket": [1, 3, 2, 4], "zipCode": 3933, "totalAmount": 164.0}
# Received answer: {"probability":0.007948292922495673}
#
# Sending request...
# {"transactionId": 9186699525, "basket": [4, 1, 1, 2, 0, 2, 4, 0, 3], "zipCode": null, "totalAmount": 117.0}
# Received answer: {"probability":0.016441651784529}
#
# Sending request...
# {"transactionId": 2578688189, "basket": [1, 4, 2, 3, 3], "zipCode": 5061, "totalAmount": 195.0}
# Received answer: {"probability":0.036241578927549076}
#
# Sending request...
# {"transactionId": 6251738604, "basket": [3, 2], "zipCode": 9578, "totalAmount": null}
# Received answer: {"probability":0.03161202566575944}
#
# Sending request...
# {"transactionId": 2004155805, "basket": [2, 2, 3, 1, 0, 2, 1], "zipCode": 5112, "totalAmount": 490.0}
# Received answer: {"probability":0.006700864237923228}
#
# Sending request...
# {"transactionId": 9846271368, "basket": [4, 2, 0, 2, 0, 0, 3], "zipCode": 8725, "totalAmount": null}
# Received answer: {"probability":0.008040682036184625}
#
# Sending request...
# {"transactionId": 9613771022, "basket": [4, 3, 1, 4, 1, 2], "zipCode": 9027, "totalAmount": 450.0}
# Received answer: {"probability":0.0020519077325779614}
#
# Sending request...
# {"transactionId": 1019921350, "basket": [3], "zipCode": 2545, "totalAmount": 51.0}
# Received answer: {"probability":0.011649254308301833}
#
# Sending request...
# {"transactionId": 2967186764, "basket": [4, 0, 3, 0, 2, 4, 1, 4, 4, 3, 0], "zipCode": 7540, "totalAmount": 374.0}
# Received answer: {"probability":0.1193851343274851}
#
# Sending request...
# {"transactionId": 7082105600, "basket": [0, 4, 1, 1, 3, 4, 4, 4], "zipCode": 8330, "totalAmount": 408.0}
# Received answer: {"probability":0.0027464786260984046}
#
# Sending request...
# {"transactionId": 2958146442, "basket": [0, 0, 3, 2, 2, 1], "zipCode": 7416, "totalAmount": 240.0}
# ...
#
# Sending request...
# {"transactionId": 6048115211, "basket": [2, 0], "zipCode": 8848, "totalAmount": 9.2}
# Received answer: {"probability":0.019780642511704583}
#
# Sending request...
# {"transactionId": 3718110222, "basket": [4], "zipCode": 7361, "totalAmount": 6.1}
# Received answer: {"probability":0.009035604618802805}
#
# Sending request...
# {"transactionId": 1501409245, "basket": [0, 1, 2], "zipCode": 3875, "totalAmount": 9.3}
# Received answer: {"probability":0.0021696273198809147}
#
# Sending request...
# {"transactionId": 5954240060, "basket": [2, 3, 4, 3, 3, 4], "zipCode": 2518, "totalAmount": 23.4}
# Received answer: {"probability":0.3402440710235731}
#
# Sending request...
# {"transactionId": 2306447956, "basket": [1], "zipCode": 2365, "totalAmount": 10.4}
# Received answer: {"probability":0.009270536072001309}
#
# Sending request...
# {"transactionId": 5269054458, "basket": [2, 1, 0, 2, 0], "zipCode": null, "totalAmount": 33.5}
# Received answer: {"probability":0.006628179684137123}
#
# Sending request...
# {"transactionId": 7584107773, "basket": [1, 3, 4, 1, 0, 3], "zipCode": 8429, "totalAmount": 29.4}
# Received answer: {"probability":0.05317799327424457}
#
# Sending request...
# {"transactionId": 8938600996, "basket": [4, 3, 3, 3, 0], "zipCode": 8343, "totalAmount": 14.5}
# Received answer: {"probability":0.003442643966515672}
#
# Sending request...
# {"transactionId": 6263616696, "basket": [0, 1, 2, 3, 4], "zipCode": null, "totalAmount": 22.5}
# Received answer: {"probability":0.0020364020478717444}
#
# Sending request...
# {"transactionId": 7758558469, "basket": [1, 1, 1, 0, 1, 0, 4], "zipCode": 2492, "totalAmount": null}
# Received answer: {"probability":0.0006492067245691617}
#
# Sending request...
# {"transactionId": 2799037924, "basket": [4, 4, 0, 3, 1, 4, 3], "zipCode": 1318, "totalAmount": 11.2}
# Received answer: {"probability":0.006444477199905201}
#
# Sending request...
# {"transactionId": 3702233807, "basket": [1, 3, 4, 3, 3, 2, 0, 2, 2], "zipCode": 9322, "totalAmount": 51.3}
# Received answer: {"probability":0.008629604377346469}
#
# Sending request...
# {"transactionId": 2889060031, "basket": null, "zipCode": null, "totalAmount": 8.0}
# Received answer: {"probability":0.006445836580071383}
#
# Sending request...
# {"transactionId": 4465588589, "basket": null, "zipCode": null, "totalAmount": 53.9}
# Received answer: {"probability":0.01284208706688913}
#
# Sending request...
# {"transactionId": 9131326796, "basket": [3, 0, 3], "zipCode": 1309, "totalAmount": null}
# Received answer: {"probability":0.021120732275288594}
#
# Sending request...
# {"transactionId": 9297363347, "basket": [0, 2, 1, 1], "zipCode": 7203, "totalAmount": 9.2}
# Received answer: {"probability":0.006629612954385089}
#
# Sending request...
# {"transactionId": 1285567046, "basket": [3, 2, 3, 1, 4, 2, 0, 0, 3, 0, 3], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.006454535292777398}
#
# Sending request...
# {"transactionId": 3312382917, "basket": [1, 2, 2, 0, 4], "zipCode": 6892, "totalAmount": null}
# Received answer: {"probability":0.0011058145836233182}
#
# Sending request...
# {"transactionId": 5547181799, "basket": [3, 1, 0, 4, 2, 3, 0, 1, 1, 3], "zipCode": 9468, "totalAmount": 10.0}
# Received answer: {"probability":0.0003792873048286435}
#
# Sending request...
# {"transactionId": 8938645936, "basket": [0, 1, 3, 2], "zipCode": 7402, "totalAmount": 19.6}
# Received answer: {"probability":0.03625927518430299}
#
# Sending request...
# {"transactionId": 6866808271, "basket": [1, 0], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.06868870542246402}
#
# Sending request...
# {"transactionId": 8234893281, "basket": [4, 3, 4, 3, 4], "zipCode": 6252, "totalAmount": 18.0}
# Received answer: {"probability":0.008693671230467052}
#
# Sending request...
# {"transactionId": 9649749319, "basket": [0, 2, 4, 4, 0, 1, 4], "zipCode": 2754, "totalAmount": 16.1}
# Received answer: {"probability":0.009044134053713777}
#
# Sending request...
# {"transactionId": 7162009603, "basket": null, "zipCode": 9265, "totalAmount": 16.1}
# Received answer: {"probability":0.006194261500004965}
#
# Sending request...
# {"transactionId": 7234018744, "basket": [1, 0], "zipCode": 7915, "totalAmount": 16.6}
# Received answer: {"probability":0.22389167850347041}
#
# Sending request...
# {"transactionId": 4388665000, "basket": [0, 3], "zipCode": 5377, "totalAmount": 7.2}
# Received answer: {"probability":0.0017220440689795617}
#
# Sending request...
# {"transactionId": 2832554069, "basket": null, "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.3024073837449521}
#
# Sending request...
# {"transactionId": 8996739781, "basket": [0, 3, 4, 3], "zipCode": 2144, "totalAmount": 14.0}
# Received answer: {"probability":0.00646925743459675}
#
# Sending request...
# {"transactionId": 9309037340, "basket": [2, 3, 1, 4, 1, 0], "zipCode": 4722, "totalAmount": 6.0}
# Received answer: {"probability":0.0012903826663530134}
#
# Sending request...
# {"transactionId": 7736648738, "basket": [2, 2, 1], "zipCode": 4160, "totalAmount": 25.2}
# Received answer: {"probability":0.005942922442991415}
#
# Sending request...
# {"transactionId": 4661604180, "basket": [0, 2], "zipCode": 6676, "totalAmount": 12.0}
# Received answer: {"probability":0.0024578339436121493}
#
# Sending request...
# {"transactionId": 4575775587, "basket": [4, 2, 4, 4], "zipCode": null, "totalAmount": 19.2}
# Received answer: {"probability":0.014957892644522908}
#
# Sending request...
# {"transactionId": 5910174358, "basket": [0, 3, 4, 4], "zipCode": null, "totalAmount": null}
# Received answer: {"probability":0.006301121343607535}
#
# Sending request...
# {"transactionId": 1944156667, "basket": [0, 1, 1, 4, 1, 3, 1], "zipCode": 6742, "totalAmount": 63.7}
# Received answer: {"probability":0.007230266399495667}
#
# Sending request...
# {"transactionId": 5200839676, "basket": [2, 3], "zipCode": 4687, "totalAmount": null}
# Received answer: {"probability":0.007880497765446045}
#
# Sending request...
# {"transactionId": 2149007894, "basket": null, "zipCode": 9902, "totalAmount": 30.6}
# Received answer: {"probability":0.008486564650019809}
#
# Sending request...
# {"transactionId": 2737789821, "basket": [2, 1, 0], "zipCode": 3255, "totalAmount": null}
# Received answer: {"probability":0.025808375359581522}
#
# Sending request...
# {"transactionId": 8262208499, "basket": [1, 2, 3], "zipCode": 9531, "totalAmount": 3.0}
# Received answer: {"probability":0.008431326059851514}
#
# Sending request...
# {"transactionId": 9077451649, "basket": [3, 3, 4, 3, 3, 3], "zipCode": 4861, "totalAmount": 38.4}
# Received answer: {"probability":0.00529586608721682}
#
# Sending request...
# {"transactionId": 8184175930, "basket": [1, 2, 3, 0, 4], "zipCode": 5049, "totalAmount": 5.0}
# Received answer: {"probability":0.000524722947911522}
#
# Sending request...
# {"transactionId": 4272134136, "basket": null, "zipCode": 6217, "totalAmount": 29.7}
# Received answer: {"probability":0.0003137406706183084}
#
# Sending request...
# {"transactionId": 1976470198, "basket": null, "zipCode": null, "totalAmount": 28.2}
# Received answer: {"probability":0.03494842142968327}
#
# Sending request...
# {"transactionId": 3170781958, "basket": [4, 2, 3, 0, 0], "zipCode": 1088, "totalAmount": 61.0}
# Received answer: {"probability":0.006370037031464952}
#
# Sending request...
# {"transactionId": 5730930841, "basket": [4, 1, 4, 1, 1], "zipCode": 4680, "totalAmount": 34.0}
# Received answer: {"probability":0.009470886905366868}
#
# Sending request...
# {"transactionId": 1874848403, "basket": [0, 4, 2], "zipCode": 5965, "totalAmount": null}
# Received answer: {"probability":0.4663034333600659}
#
# Sending request...
# {"transactionId": 2319731745, "basket": [1, 4, 3, 4], "zipCode": 8032, "totalAmount": 19.2}
# Received answer: {"probability":0.006314416829451162}
#
# Sending request...
# {"transactionId": 7854275531, "basket": null, "zipCode": 8847, "totalAmount": 4.5}
# Received answer: {"probability":0.020211379411942856}
#
# Sending request...
# {"transactionId": 8655484612, "basket": [3, 3, 0, 2, 2, 0, 4], "zipCode": 1821, "totalAmount": 7.0}
# Received answer: {"probability":0.00614815519071894}
#
# Sending request...
# {"transactionId": 1370359564, "basket": [0, 0, 1, 2, 0, 3, 4], "zipCode": 9119, "totalAmount": 34.3}
# Received answer: {"probability":0.006556165489496679}
#
# Sending request...
# {"transactionId": 1635567399, "basket": [2, 3, 3, 2], "zipCode": 4551, "totalAmount": 20.4}
# Received answer: {"probability":0.022469589938271757}
#
# Sending request...
# {"transactionId": 9246506815, "basket": null, "zipCode": 6307, "totalAmount": 27.6}
# Received answer: {"probability":0.020056769875096365}
#
# Sending request...
# {"transactionId": 2316410360, "basket": [3, 2, 1, 2, 2, 0, 4], "zipCode": null, "totalAmount": 30.1}
# Received answer: {"probability":0.01860506406721903}
#
# Sending request...
# {"transactionId": 8178202184, "basket": [4, 2, 4, 0, 1, 3, 2, 1, 4, 3], "zipCode": 7773, "totalAmount": 43.0}
# Received answer: {"probability":0.0037663426646402697}
#
# Sending request...
# {"transactionId": 3651349134, "basket": [0, 2, 2, 4, 4], "zipCode": null, "totalAmount": 5.5}
# Received answer: {"probability":0.004253488401289802}
#
# Sending request...
# {"transactionId": 1219831571, "basket": [1, 0, 4, 3, 4, 0, 4], "zipCode": 9195, "totalAmount": 21.7}
# Received answer: {"probability":0.010381167310091552}
#
# Sending request...
# {"transactionId": 4038619250, "basket": [1, 1, 1, 0], "zipCode": null, "totalAmount": 12.8}
# Received answer: {"probability":0.028979018945655934}
#
# Sending request...
# {"transactionId": 4999416006, "basket": [4, 1], "zipCode": 9427, "totalAmount": 13.4}
# Received answer: {"probability":0.008452622438896865}
#
# Sending request...
# {"transactionId": 9660244504, "basket": [3, 1, 1], "zipCode": 1575, "totalAmount": 3.0}
# Received answer: {"probability":0.006932000424923818}
#
# Sending request...
# {"transactionId": 9941565663, "basket": [2], "zipCode": 1160, "totalAmount": 1.8}
# Received answer: {"probability":0.0004121454351679445}
#
# Sending request...
# {"transactionId": 9825514625, "basket": [2, 1, 2, 0, 3, 1], "zipCode": 6235, "totalAmount": 29.4}
# Received answer: {"probability":0.012113423655611714}
#
# Sending request...
# {"transactionId": 7379656884, "basket": [0], "zipCode": 5928, "totalAmount": 7.1}
# Received answer: {"probability":0.008356532270593992}
#
# Sending request...
# {"transactionId": 4944192009, "basket": [2], "zipCode": 5440, "totalAmount": 1.0}
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\Anaconda3\envs\dsr\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ConnectionRefusedError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-8122e0ddc9fa> in <module>()
#       3     headers = {'content-type': 'application/json'}
#       4     print(jsonLine(i))
# ----> 5     r = requests.post("http://localhost:5000/predict", data=jsonLine(i), headers=headers)
#       6     print("Received answer: " + str(r.text))
#       7     #time.sleep(1)
#
# ~\Anaconda3\envs\dsr\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# ~\Anaconda3\envs\dsr\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\envs\dsr\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~\Anaconda3\envs\dsr\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\dsr\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     443                     decode_content=False,
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#     447
#
# ~\Anaconda3\envs\dsr\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\envs\dsr\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     352             conn.request_chunked(method, url, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# ~\Anaconda3\envs\dsr\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\Anaconda3\envs\dsr\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# ~\Anaconda3\envs\dsr\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# ~\Anaconda3\envs\dsr\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# ~\Anaconda3\envs\dsr\lib\http\client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# ~\Anaconda3\envs\dsr\lib\site-packages\urllib3\connection.py in connect(self)
#     194
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#     198
#
# ~\Anaconda3\envs\dsr\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     169         try:
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#     173         except SocketTimeout as e:
#
# ~\Anaconda3\envs\dsr\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      67             if source_address:
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#      71
#
# KeyboardInterrupt:
